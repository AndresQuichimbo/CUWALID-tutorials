# %%
################
from cuwalid.dryp.main_DRYP import run_DRYP

input_path = "C:/Users/oshin/OneDrive - Cardiff University/CLARITY/Work_Niger+Nigeria/model/mk_jibiya/inputfiles/"
input_file = input_path + "mk_tlab_model_input_t2a.json"

run_DRYP(input_file)
# Out:
# reading config file...
#
# ...
#
# Reading settings file...
#
# ...
# Store variable option not provided, default parameters applied
# Model Name:  MK_TLab_sim_t2a
# ********************* Output Directory **********************
# Directory  C:/Users/oshin/OneDrive - Cardiff University/CLARITY/Work_Niger+Nigeria/model/mk_jibiya/outputs  already exists
# ***************************** READING MODEL PARAMETERS *****************************
#
# reading config file...
#
# ...
#
# Reading settings file...
#
# ...
# Store variable option not provided, default parameters applied
# Model Name:  MK_TLab_sim_t2a
# ********************* Output Directory **********************
# Directory  C:/Users/oshin/OneDrive - Cardiff University/CLARITY/Work_Niger+Nigeria/model/mk_jibiya/outputs  already exists
# ====== > Reading surface and river network parameters
# Basin boundary...................not provided
# Lake bathymetry..................not provided. Global default z
# Channel decay parameter..........not provided
# ...
