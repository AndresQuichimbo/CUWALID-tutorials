# %%
#####
import cuwalid.dryp.components.DRYP_watershed as ppbasin  
import cuwalid.tools.DRYP_pptools as pptools    
import cuwalid.tools.DRYP_rrtools as rrtools  
#####
fname = "C:/Users/oshin/OneDrive - Cardiff University/CLARITY/Work_Niger+Nigeria/model/mk_jibiya/mk_flowdirection_agnps_clipped.asc"
fout = "C:/Users/oshin/OneDrive - Cardiff University/CLARITY/Work_Niger+Nigeria/model/mk_jibiya/mk_flowdirection_agnps_clipped_landlab.asc"
#####
rrtools.create_raster_flowdirection_dryp(fname, fout, format_data = 'AGNPS')
