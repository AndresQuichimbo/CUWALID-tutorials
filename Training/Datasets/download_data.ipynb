# %% [markdown]
# # HYDROAWARE - AFRICA project

# %% [markdown]
# Download climatology data for the HAD region

# %%
# 1. Install or upgrade the gdown package
#!pip install --upgrade gdown

import gdown

# --- SPECIFY YOUR DESTINATION FOLDER HERE ---
# This creates a folder named "my_dataset_folder" in your current directory
destination_path = '/home/chc-andres/AF/historical/regional/datasets'

# 2. Define the folder URL and ID
folder_id = '19B45lOKfO-49CDY9Y5RaFktOqoUu0WM1'
url = f'https://drive.google.com/drive/folders/{folder_id}?usp=sharing'

# Download directly into that specific folder
gdown.download_folder(url, output=destination_path, use_cookies=False)

# %% [markdown]
# Download continental data for Africa, only parameters

# %%
# 1. Install or upgrade the gdown package
#!pip install --upgrade gdown

import gdown

# --- SPECIFY YOUR DESTINATION FOLDER HERE ---
# This creates a folder named "my_dataset_folder" in your current directory
destination_path = '/home/chc-andres/AF/historical/continental/'

# 2. Define the folder URL and ID
folder_id = '19B45lOKfO-49CDY9Y5RaFktOqoUu0WM1'
url = f'https://drive.google.com/drive/folders/{folder_id}?usp=sharing'

# Download directly into that specific folder
gdown.download_folder(url, output=destination_path, use_cookies=False)
